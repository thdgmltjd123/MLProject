# %% [markdown]
# <a href="https://colab.research.google.com/github/thdgmltjd123/Assignment01/blob/master/Assignment10_20150711.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 구글 드라이브와 코랩 마운트하기
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # ***Computation Area***

# %%
import torch
import torch.nn as nn
from torch.utils.data import random_split
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torchvision import transforms, datasets
import numpy as np
import pandas as pd

# %%
transform = transforms.Compose([
      transforms.ToTensor(),
      transforms.Normalize((0.1307,),(0.3081,)),
])

# %%
# 부모클래스 nn.Module로부터 상속받는 자식클래스 classification
class classification(nn.Module):
  def __init__(self):
    # 부모클래스의 생성자를 이용하겠다.
    super(classification, self).__init__()

    # layer 1층 : 28*28 데이터가 20*20으로 나옴
    # activation_function = Sigmoid
    self.classifier1 = nn.Sequential(
        nn.Linear(in_features = 28*28, out_features=600),
        nn.ReLU(),
        nn.Dropout(p = 0.5),
    )
    # layer 2층 : 20*20 데이터가 10*10으로 나옴
    # activation_function = Sigmoid
    self.classifier2 = nn.Sequential(
        nn.Linear(in_features = 600, out_features = 300),
        nn.ReLU(),
        nn.Dropout(p = 0.5)
    )
    # output layer 3층 : 10*10 데이터가 10으로 나옴
    # activation_function = LogSoftmax
    self.classifier3 = nn.Sequential(
        nn.Linear(in_features=300, out_features = 10),
    )
  # 순전파 알고리즘
  def forward(self, inputs):
    x = inputs.view(inputs.size(0),-1)
    x = self.classifier1(x)
    x = self.classifier2(x)
    out = self.classifier3(x)

    return out

# %%
# fully-connected Neural Network using Pytorch
def fc_NN(train_loader, test_loader, epoch, learning_rate, no_cuda = False):
  use_cuda = not no_cuda and torch.cuda.is_available()
  device = torch.device("cuda" if use_cuda else "cpu")
  Model = classification().to(device)
  optimizer = torch.optim.ASGD(Model.parameters(), lr = learning_rate)
  train_L_iters = []
  train_acc_iters = []
  test_L_iters = []
  test_acc_iters = []
  for i in range(1,epoch+1):
    # Train mode
    train_loss = 0
    train_correct = 0
    Model.train()
    for batch_idx,(data, target) in enumerate(train_loader):
      # data와 target을 gpu를 사용할 수 있게 매핑
      data, target = data.to(device), target.to(device)
      # backward하는 과정에서 기존의 gradient값에 새로운 gradient 값을
      # 더해주기때문에 grad값을 매 backward마다 0으로 초기화해줘야 올바른 학습이 가능
      optimizer.zero_grad()
      # 순전파
      output = Model(data)
      # reduction = (default) "mean"
      loss = F.cross_entropy(output,target)
      train_loss += F.cross_entropy(output,target,reduction = 'sum').item()
      pred = output.argmax(dim = 1, keepdim = True)
      train_correct += pred.eq(target.view_as(pred)).sum().item()
      # 역전파
      loss.backward()
      optimizer.step()
    # 에포크별 평균 트레인 로스 계산
    train_loss /= len(train_loader.dataset)
    train_L_iters.append(train_loss)
    # 에포크별 평균 정확도 계산
    accuracy =  100 * train_correct / len(train_loader.dataset)
    train_acc_iters.append(accuracy)    
    # Test Mode
    Model.eval()
    test_loss = 0
    test_correct = 0
    # torch.no_grad() 테스트 할 때, 위에서 계산한 grad를 더이상 업데이트 하지 않음.
    with torch.no_grad():
      for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = Model(data)
        test_loss += F.cross_entropy(output, target, reduction = 'sum').item()
        pred = output.argmax(dim = 1, keepdim = True)
        test_correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)
    test_L_iters.append(test_loss)
    accuracy = 100 * test_correct / len(test_loader.dataset)
    test_acc_iters.append(accuracy)
    if i % 2 == 0:
      print("progress = {}, current loss = {}, current device = {}\n".format(100 * i / epoch, train_loss, torch.cuda.get_device_name()))
      print("test loss = {}".format(test_loss))    

  return train_L_iters, train_acc_iters, test_L_iters, test_acc_iters

# %%
data_path = '/content/drive/My Drive/Colab Notebooks'
temp_train = datasets.MNIST(root = data_path, train = False, 
                  download=True, transform = transform)
temp_test = datasets.MNIST(root = data_path, train = True, 
                  download=True, transform = transform)

# %%
part_test = random_split(temp_test, [10000, 50000])[0]
len(part_test)
# Out:
# 10000

# %%
# 배치사이즈별 학습
batch_size = [16,32]
epoch = 20
learning_rate_value = 0.05
no_cuda = False
# 배치사이즈별 loss and accuracy
batch_train_loss = []
batch_test_loss = []
batch_train_accuracy = []
batch_test_accuracy = []
data_path = '/content/drive/My Drive/Colab Notebooks'
# 배치사이즈별 학습
for b in batch_size:
  print("batch_size  = {}".format(b))
  train_loader = torch.utils.data.DataLoader(
                    temp_train,
                    batch_size = b,
                    shuffle = False)
  test_loader = torch.utils.data.DataLoader(
                    temp_test,
                    batch_size = b,
                    shuffle = False)
  train_L_iters, train_acc_iters,test_L_iters, test_acc_iters = fc_NN(train_loader, test_loader,epoch, learning_rate_value)
  batch_train_loss.append(train_L_iters)
  batch_train_accuracy.append(train_acc_iters)
  batch_test_loss.append(test_L_iters)
  batch_test_accuracy.append(test_acc_iters)
# Out:
# batch_size  = 16
# progress = 10.0, current loss = 0.2938188611399382, current device = Tesla T4
#
# test loss = 0.27938622021768245
# progress = 20.0, current loss = 0.1828996990912594, current device = Tesla T4
#
# test loss = 0.22702308777681707
# progress = 30.0, current loss = 0.13569717528345063, current device = Tesla T4
#
# test loss = 0.2040300880788942
# progress = 40.0, current loss = 0.09444053878617414, current device = Tesla T4
#
# test loss = 0.1861416532259238
# progress = 50.0, current loss = 0.07731402098468389, current device = Tesla T4
#
# test loss = 0.190969860892604
# progress = 60.0, current loss = 0.07383579091801075, current device = Tesla T4
#
# test loss = 0.18758296689301338
# progress = 70.0, current loss = 0.058713290791687175, current device = Tesla T4
#
# test loss = 0.19077239169613033
# progress = 80.0, current loss = 0.04978907007098314, current device = Tesla T4
#
# test loss = 0.18563854374466368
# progress = 90.0, current loss = 0.04242825069556493, current device = Tesla T4
#
# test loss = 0.1829243450614285
# progress = 100.0, current loss = 0.03595446841260418, current device = Tesla T4
#
# test loss = 0.18691808789641381
# batch_size  = 32
# progress = 10.0, current loss = 0.3451918559134006, current device = Tesla T4
#
# test loss = 0.2740115833034118
# progress = 20.0, current loss = 0.2014969651065767, current device = Tesla T4
#
# test loss = 0.22116561595561604
# progress = 30.0, current loss = 0.14692607016339898, current device = Tesla T4
#
# test loss = 0.20037127255996068
# progress = 40.0, current loss = 0.11114698203206062, current device = Tesla T4
#
# test loss = 0.17637735244805613
# progress = 50.0, current loss = 0.08465472006406635, current device = Tesla T4
#
# test loss = 0.17339489014218562
# progress = 60.0, current loss = 0.07071004421357066, current device = Tesla T4
#
# test loss = 0.1659046283411871
# progress = 70.0, current loss = 0.05866030301549472, current device = Tesla T4
#
# test loss = 0.16846313821414952
# progress = 80.0, current loss = 0.046421887663332745, current device = Tesla T4
#
# test loss = 0.16895618608840354
# progress = 90.0, current loss = 0.03855120967268012, current device = Tesla T4
#
# test loss = 0.17573841954608604
# progress = 100.0, current loss = 0.0348276062021614, current device = Tesla T4
#
# test loss = 0.16953537304557975

# %%
print(max(batch_test_accuracy[0]))
print(max(batch_test_accuracy[1]))
print(min(batch_test_loss[0]))
print(min(batch_test_loss[1]))
print(batch_test_accuracy[0][-1])
print(batch_test_accuracy[1][-1])
print(batch_test_loss[0][-1])
print(batch_test_loss[1][-1])
# Out:
# 96.03
# 95.85833333333333
# 0.17526603422814369
# 0.16214336897034276
# 96.0
# 95.85833333333333
# 0.18691808789641381
# 0.16953537304557975

# %% [markdown]
# # ***Output Area***

# %% [markdown]
# # **[Output] Plot the Training and testing losses with a batch size of 16**

# %%
plt.figure(figsize = (7,7))
plt.plot(batch_train_loss[0], c = "red", label = "train loss")
plt.plot(batch_test_loss[0], c = "blue", label = "test loss")
plt.title("loss at batch_size = 16")
plt.legend(loc = "best")
plt.show()

# %% [markdown]
# # **[Output] Plot the training and testing accuracies with a batch size of 16**

# %%
plt.figure(figsize = (7,7))
plt.plot(batch_train_accuracy[0], c = "red", label = "train accuracy")
plt.plot(batch_test_accuracy[0], c = "blue", label = "test accuracy")
plt.title("accuracy at batch_size = 16")
plt.legend(loc = "best")
plt.show()

# %% [markdown]
# # **[Output] Plot the training and testing losses with a batch size of 32**

# %%
plt.figure(figsize = (7,7))
plt.plot(batch_train_loss[1], c = "red", label = "train loss")
plt.plot(batch_test_loss[1], c = "blue", label = "test loss")
plt.title("loss at batch_size = 32")
plt.legend(loc = "best")
plt.show()

# %% [markdown]
# # **[Output] Plot the training and testing accuracies with a batch size of 32**

# %%
plt.figure(figsize = (7,7))
plt.plot(batch_train_accuracy[1], c = "red", label = "train accuracy")
plt.plot(batch_test_accuracy[1], c = "blue", label = "test accuracy")
plt.title("accuracy at batch_size = 32")
plt.legend(loc = "best")
plt.show()

# %% [markdown]
# # **[Output] Print the loss at convergence with different mini-batch sizes**

# %%
columns = ["loss"," "]
cellText = [["training", round(batch_train_loss[0][-1],2)],
            ["testing", round(batch_test_loss[0][-1],2)]]
colors = ["#ccd9eb","#ccd9eb"]
fig, ax = plt.subplots(figsize = (5,5))
plt.axis("off")
table = ax.table(cellText = cellText,
                 colLabels = columns,
                 colColours = colors,
                 loc = "top",
                 )
table.set_fontsize(100)
table.scale(2,8)

# %% [markdown]
# # **[Output] Print the accuracy at convergence with different mini-batch sizes**

# %%
columns = ["accuracy"," "]
cellText = [["training", round(batch_train_accuracy[0][-1],2)],
            ["testing", round(batch_test_accuracy[0][-1],2)]]
colors = ["#ccd9eb","#ccd9eb"]
fig, ax = plt.subplots(figsize = (5,5))
plt.axis("off")
table = ax.table(cellText = cellText,
                 colLabels = columns,
                 colColours = colors,
                 loc = "top"
                 )
table.set_fontsize(100)
table.scale(2,8)
