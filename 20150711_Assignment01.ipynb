# %% [markdown]
# <a href="https://colab.research.google.com/github/thdgmltjd123/Assignment01/blob/master/20150711_Assignment01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#구글 코랩 깃헙 private repository에 연동해서 저장하기#

# %% [markdown]
# ***데이터 생성 및 시각화***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
#define x, y = ax + b and noise ~ N(0,2) 
mu, sigma = 0, 2
x = np.random.randint(-10,10,size = 500) + np.random.rand(500)
a , b = -0.8, 30
y = a*x + b
#plotting a graph
plt.figure(figsize = (8,6))
plt.title("Data Generation",fontsize = 30)
plt.xlabel("X",fontsize = 15)
plt.ylabel("Y",fontsize = 15)
plt.plot(x,y, linewidth = 3, color = "blue")
n = np.random.normal(mu,sigma,500)
y = y + n
plt.scatter(x,y,c = "black")

# %% [markdown]
# # **Linear Regression 구현**

# %%
#initialize theta
np.random.seed(200)
theta0 = float(np.random.rand(1) + np.random.randint(-100,100))
theta1 = float(np.random.rand(1) + np.random.randint(-5,5))

theta0_val = []
theta1_val = []
energy_val = []

alpha = 0.01

epochs = 500

for epoch in range(epochs):
    hx = theta0 + theta1*x
    energy = np.sum((hx-y)**2) / 2*500
    theta0_val.append(theta0)
    theta1_val.append(theta1)
    energy_val.append(energy)
    gra_theta0 = np.sum((hx-y)) / 500
    gra_theta1 = np.sum((hx-y)*x) / 500
    theta0 -= alpha * gra_theta0
    theta1 -= alpha * gra_theta1

# %% [markdown]
# # **결과 값 시각화**

# %%
plt.figure(figsize = (8,6))
plt.title("After LR",fontsize = 30)
plt.xlabel("X",fontsize = 15)
plt.ylabel("Y",fontsize = 15)
plt.scatter(x,y, color = "black")
plt.plot(x,hx,linewidth = 3,c = "red")

# %%
plt.figure(figsize = (8,6))
plt.title("Energy graph", fontsize = 30)
plt.xlabel("Epochs",fontsize = 15)
plt.ylabel("Energy",fontsize = 15)
plt.plot(np.arange(len(energy_val)),energy_val, c = "blue", linewidth = 3)
