# %% [markdown]
# <a href="https://colab.research.google.com/github/thdgmltjd123/Assignment01/blob/master/assignment_05_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Supervised classification - improving capacity learning
# <hr>
#
# ## 0. Import library
# <hr>
# Import library

# %%
#구글 드라이브와 코랩 마운트하기
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import libraries

# math library
import numpy as np

# visualization library
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png2x','pdf')
import matplotlib.pyplot as plt

# machine learning library
from sklearn.linear_model import LogisticRegression

# 3d visualization
from mpl_toolkits.mplot3d import axes3d

# computational time
import time

import math

# %% [markdown]
# ## 1. Load and plot the dataset (dataset-noise-02.txt)
# <hr>
# The data features for each data $i$ are $x_i=(x_{i(1)},x_{i(2)})$.
#
# The data label/target, $y_i$, indicates two classes with value 0 or 1.
#
# Plot the data points.
#
# You may use matplotlib function `scatter(x,y)`.

# %%
# import data with numpy
data = np.loadtxt('/content/drive/My Drive/Colab Notebooks/dataset-b.txt', delimiter=',')

# number of training data
n = data.shape[0] 
print('Number of the data = {}'.format(n))
print('Shape of the data = {}'.format(data.shape))
print('Data type of the data = {}'.format(data.dtype))

# plot
x1 = data[:,0] # feature 1
x2 = data[:,1] # feature 2
idx = data[:,2] # label

idx_class0 = data[idx == 0]  # index of class0
idx_class1 = data[idx == 1]  # index of class1

plt.figure(1,figsize=(10,10))
plt.scatter(idx_class0[:,0], idx_class0[:,1], s=50, c='r', marker='.', label='class=0') 
plt.scatter(idx_class1[:,0], idx_class1[:,1], s=50, c='b', marker='.', label='class=1')
plt.title('Training data')
plt.legend(loc = 'best')
plt.show()
# Out:
# Number of the data = 1000
# Shape of the data = (1000, 3)
# Data type of the data = float64

# %% [markdown]
# ## 2. Define a logistic regression loss function and its gradient
# <hr>

# %%
# sigmoid function
def sigmoid(z):
    sigmoid_f = 1 / (1 + np.exp(-z))
    return sigmoid_f 
# predictive function definition
def f_pred(X,w): 
    p = sigmoid(np.dot(X,w))
    return p
# loss function definition
def loss_logreg(y_pred,y): 
    n = len(y)
    loss = np.mean(-y * np.log(y_pred + 1e-7) - (1 - y) * np.log(1 - y_pred + 1e-7))
    return loss
# gradient function definition
def grad_loss(y_pred,y,X):
    n = len(y)
    grad = (2 * np.dot(X.T,y_pred - y)) / n
    return grad
# gradient descent function definition
def grad_desc(X, y , w_init, tau, max_iter):

    L_iters = np.zeros([max_iter]) # record the loss values
    w = w_init # initialization
    for i in range(max_iter): # loop over the iterations
        y_pred = f_pred(X,w)  # linear predicition function   
        grad_f = grad_loss(y_pred,y,X)  # gradient of the loss  
        w = w - tau * grad_f  # update rule of gradient descent  
        L_iters[i] = loss_logreg(y_pred, y) # save the current loss value 
        
    return w, L_iters

# %% [markdown]
# ## 3. define a prediction function and run a gradient descent algorithm
# <hr>
#
# The logistic regression/classification predictive function is defined as:
#
# $$
# \begin{aligned}
# p_w(x) &= \sigma(X w)
# \end{aligned}
# $$
#
# The prediction function can be defined in terms of the following feature functions $f_i$ as follows:
#
# $$
# X =
# \left[
# \begin{array}{cccccc}
# f_0(x_1) & f_1(x_1) & f_2(x_1) & f_3(x_1) & f_4(x_1) & f_5(x_1) & f_6(x_1) & f_7(x_1) & f_8(x_1) & f_9(x_1) \\
# f_0(x_2) & f_1(x_2) & f_2(x_2) & f_3(x_2) & f_4(x_2) & f_5(x_2) & f_6(x_2) & f_7(x_2) & f_8(x_2) & f_9(x_2) \\
# \vdots\\
# f_0(x_n) & f_1(x_n) & f_2(x_n) & f_3(x_n) & f_4(x_n) & f_5(x_n) & f_6(x_n) & f_7(x_n) & f_8(x_n) & f_9(x_n) \\
# \end{array}
# \right]
# \quad
# \textrm{ and }
# \quad
# w =
# \left[
# \begin{array}{cccc}
# w_0 \\
# w_1 \\
# w_2 \\
# w_3 \\
# w_4 \\
# w_5 \\
# w_6 \\
# w_7 \\
# w_8 \\
# w_9
# \end{array}
# \right]
# \quad
# $$
#
# where $x_i = (x_i(1), x_i(2))$ and you can define a feature function $f_i$ as you want.
#
# You can use at most 10 feature functions $f_i$, $i = 0, 1, 2, \cdots, 9$ in such a way that the classification accuracy is maximized. You are allowed to use less than 10 feature functions.
#
# Implement the logistic regression function with gradient descent using a vectorization scheme.

# %%
import math
# construct the data matrix X, and label vector y
n = data.shape[0]
X = np.ones([n,10])
X[:,1] = x1
X[:,2] = x2
X[:,3] = x1 * x2
X[:,4] = x1 ** 2
X[:,5] = x2 ** 2
X[:,6] = (x1 ** 2) * x2
X[:,7] = (x2 ** 2) * x1
X[:,8] = (x1 ** 2) * (x2 ** 2)
X[:,9] = x1**3

y = data[:,2][:,None] # label 


# run gradient descent algorithm
start = time.time()
w_init = np.array([-10,-3,1,-1,-0.5,4.2,0.8,-4,-2.1,3.4])[:,None]
tau = 1e-2; max_iter = 30000
w, L_iters = grad_desc(X, y , w_init, tau, max_iter)

# plot
plt.figure(3, figsize=(10,6))
plt.plot(np.array(range(max_iter)), L_iters)
plt.xlabel('Iterations')
plt.ylabel('Loss value')
plt.show()

# %% [markdown]
# ## 4. Plot the decisoin boundary
# <hr>

# %%
# compute values p(x) for multiple data points x
x1_min, x1_max = min(x1), max(x1) # min and max of grade 1
x2_min, x2_max = min(x2), max(x2) # min and max of grade 2
xx1, xx2 = np.meshgrid(np.linspace(x1_min-1,x1_max+1,60),np.linspace(x2_min-1,x2_max+1,60)) # create meshgrid
X2 = np.ones([60,60,10])
X2[:,:,1] = xx1
X2[:,:,2] = xx2
X2[:,:,3] = xx1 * xx2
X2[:,:,4] = xx1 ** 2
X2[:,:,5] = xx2 ** 2
X2[:,:,6] = (xx1 ** 2) * xx2
X2[:,:,7] = (xx2 ** 2) * xx1
X2[:,:,8] = (xx1 ** 2) * (xx2 **2)
X2[:,:,9] = xx1 ** 3

p = f_pred(X2,w)
p = p.reshape(60,60)

# plot
plt.figure(4,figsize=(12,10))

#ax = plt.contourf(xx1,xx2,p,100,vmin=0,vmax=1,cmap='coolwarm', alpha=0.6)
#cbar = plt.colorbar(ax)
#cbar.update_ticks()

plt.scatter(idx_class0[:,0],idx_class0[:,1], s=50, c='r', marker='.', label='Class=0')
plt.scatter(idx_class1[:,0],idx_class1[:,1], s=50, c='b', marker='.', label='Class=1')
plt.contour(xx1, xx2, p, levels = [0.5], linewidths=2, colors='k') 
plt.legend(loc = 'best')
plt.title('Decision boundary(quadratic)')
plt.show()

# %% [markdown]
# ## 5. Plot the probability map
# <hr>

# %%
# compute values p(x) for multiple data points x
x1_min, x1_max = min(x1), max(x1) # min and max of grade 1
x2_min, x2_max = min(x2), max(x2) # min and max of grade 2
xx1, xx2 = np.meshgrid(np.linspace(x1_min-1,x1_max+1,60),np.linspace(x2_min-1,x2_max+1,60)) # create meshgrid
X2 = np.ones([60,60,10])
X2[:,:,1] = xx1
X2[:,:,2] = xx2
X2[:,:,3] = xx1 * xx2
X2[:,:,4] = xx1 ** 2
X2[:,:,5] = xx2 ** 2
X2[:,:,6] = (xx1 ** 2) * xx2
X2[:,:,7] = (xx2 ** 2) * xx1
X2[:,:,8] = (xx1 ** 2) * (xx2 **2)
X2[:,:,9] = xx1 ** 3

p = f_pred(X2,w)
p = p.reshape(60,60)

# plot
plt.figure(4,figsize=(12,10))

ax = plt.contourf(xx1, xx2, p, 100, vmin=0, vmax=1, cmap='coolwarm', alpha=0.6)
cbar = plt.colorbar(ax)
cbar.update_ticks()

plt.scatter(idx_class0[:,0],idx_class0[:,1], s=50, c='r', marker='.', label='Class=0')
plt.scatter(idx_class1[:,0],idx_class1[:,1], s=50, c='b', marker='.', label='Class=1')
plt.contour(xx1, xx2, p, levels = [0.5], linewidths=2, colors='k') 
plt.legend(loc = 'best')
plt.title('Decision boundary(quadratic)')
plt.show()

# %% [markdown]
# ## 6. Compute the classification accuracy
# <hr>
#
# ### The accuracy is computed by:
#
# $$
# \textrm{accuracy} = \frac{\textrm{number of correctly classified data}}{\textrm{total number of data}}
# $$

# %%
# compute the accuracy of the classifier
n = data.shape[0]

y_pred = f_pred(X,w)

classified = np.where(y_pred>0.5,1,0)
cnt = 0
for i in y - classified:
  if i == 0:
    cnt+=1
print('total number of correctly classified data = ',cnt)
print('accuracy(%) = {}%'.format((cnt / n)*100))
# Out:
# total number of correctly classified data =  939
# accuracy(%) = 93.89999999999999%

# %% [markdown]
# ## Output using the dataset (dataset-noise-02.txt)
# <hr>

# %% [markdown]
# ## 1. Visualize the data [1pt]
# <ht>

# %%
plt.figure(1,figsize=(10,10))
plt.scatter(idx_class0[:,0], idx_class0[:,1], s=50, c='r', marker='.', label='class=0') 
plt.scatter(idx_class1[:,0], idx_class1[:,1], s=50, c='b', marker='.', label='class=1')
plt.title('Training data')
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# ## 2. Plot the loss curve obtained by the gradient descent until the convergence [2pt]
# <hr>

# %%
# plot

plt.figure(3, figsize=(10,6))
plt.plot(np.array(range(max_iter)), L_iters)
plt.xlabel('Iterations')
plt.ylabel('Loss value')
plt.show()

# %% [markdown]
# ## 3. Plot the decisoin boundary of the obtained classifier [2pt]
# <hr>

# %%
plt.figure(4,figsize=(12,10))
plt.scatter(idx_class0[:,0],idx_class0[:,1], s=50, c='r', marker='.', label='Class=0')
plt.scatter(idx_class1[:,0],idx_class1[:,1], s=50, c='b', marker='.', label='Class=1')
plt.contour(xx1, xx2, p, levels = [0.5], linewidths=2, colors='k') 
plt.legend(loc = 'best')
plt.title('Decision boundary(quadratic)')
plt.show()

# %% [markdown]
# ## 4. Plot the probability map of the obtained classifier [2pt]
# <hr>

# %%
# plot
plt.figure(4,figsize=(12,10))
ax = plt.contourf(xx1, xx2, p, 100, vmin=0, vmax=1, cmap='coolwarm', alpha=0.6)
cbar = plt.colorbar(ax)
cbar.update_ticks()
plt.scatter(idx_class0[:,0],idx_class0[:,1], s=50, c='r', marker='.', label='Class=0')
plt.scatter(idx_class1[:,0],idx_class1[:,1], s=50, c='b', marker='.', label='Class=1')
plt.contour(xx1, xx2, p, levels = [0.5], linewidths=2, colors='k') 
plt.legend(loc = 'best')
plt.title('Decision boundary(quadratic)')
plt.show()

# %% [markdown]
# ## 5. Compute the classification accuracy [1pt]
# <hr>

# %%
# compute the accuracy of the classifier
n = data.shape[0]

y_pred = f_pred(X,w)

classified = np.where(y_pred>0.5,1,0)
cnt = 0
for i in y - classified:
  if i == 0:
    cnt+=1

print('total number of data = {}'.format(n))
print('total number of correctly classified data = ',cnt)
print('accuracy(%) = {}%'.format((cnt / n)*100))
# Out:
# total number of data = 1000
# total number of correctly classified data =  939
# accuracy(%) = 93.89999999999999%
